# %%
# %run "0.8-antoniolml-grandes-numeros.ipynb"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /tmp/ipykernel_36476/1098114682.py:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins_df.mean()
# /tmp/ipykernel_36476/1658957529.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins_df.median()
# /tmp/ipykernel_36476/3242987746.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins_df.median()
# /tmp/ipykernel_36476/3242987746.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins_df.median()
# /tmp/ipykernel_36476/4261057176.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins_df.std()
# /tmp/ipykernel_36476/1306273066.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins_df.mean()-processed_penguins_df.std()
# /tmp/ipykernel_36476/1306273066.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins_df.mean()-processed_penguins_df.std()
# /tmp/ipykernel_36476/2653252021.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins_df.quantile(0.25)
# /tmp/ipykernel_36476/4193154747.py:2: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins_df.quantile(0.75)-processed_penguins_df.quantile(0.25)
# /tmp/ipykernel_36476/671757710.py:2: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins_df
# Estimated percentage of male penguins in population is: 50.1829%

# %% [markdown]
# # Estableciendo relaciones: Gráfica de puntos

# %%
sns.scatterplot(
    data=processed_penguins_df,
    x='bill_length_mm',
    y='bill_depth_mm',
    alpha=1/2,
    s=100
)
# Out:
# <AxesSubplot: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.displot(
    data=processed_penguins_df,
    x='bill_length_mm',
    y='bill_depth_mm',
    rug=True
)

# %%
sns.displot(
    data=processed_penguins_df,
    x='bill_length_mm',
    y='bill_depth_mm',
    kind='kde',
    rug=True
)

# %%
sns.jointplot(
    data=processed_penguins_df,
    x='bill_length_mm',
    y='bill_depth_mm',
    marginal_kws=dict(bins=25, fill=False)
)
